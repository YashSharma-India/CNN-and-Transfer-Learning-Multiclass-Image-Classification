# %% [markdown]
# # Construct deep architectures for CNN models
#
#
# ### **Description: Analyze percentage of dropout after every layer Interpret notation**

# %% [markdown]
# ### Algorithm:
#
# **--> Step 1:** Open preprocessed dataset
# **--> Step 2:** Convert classes vectors to binary matrices
# **--> Step 3:** Choose **percentage of dropout**
# **--> Step 4:** Visualize built CNN models
# **--> Step 5:** Set up learning rate & epochs
# **--> Step 6:** Train built CNN models
# **--> Step 7:** Show and plot accuracies
# **--> Step 8:** Make a conclusion
#
#
# **Result:**
# - Chosen architecture for every preprocessed dataset

# %% [markdown]
# ## Importing libraries

# %%
# Importing needed libraries
import matplotlib.pyplot as plt
import numpy as np
import h5py


from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense
from tensorflow.keras.callbacks import LearningRateScheduler
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Setting up full path to preprocessed datasets

# %%
# Full or absolute path to preprocessed datasets
full_path_to_code = \
    'C:/Users/yashs/PycharmProjects/InternshipCNN/TCS'
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 9

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Opening preprocessed dataset

# %%
# Opening saved custom dataset from HDF5 binary file
# Initiating File object
# Opening file in reading mode by 'r'
with h5py.File(full_path_to_code + '/' + 'custom' + '/' + 
               'dataset_custom_rgb_255_mean_std.hdf5', 'r') as f:
    
    # Showing all keys in the HDF5 binary file
    print(list(f.keys()))
    
    # Extracting saved arrays for training by appropriate keys
    # Saving them into new variables
    x_train = f['x_train']  # HDF5 dataset
    y_train = f['y_train']  # HDF5 dataset
    # Converting them into Numpy arrays
    x_train = np.array(x_train)  # Numpy arrays
    y_train = np.array(y_train)  # Numpy arrays
    
    
    # Extracting saved arrays for validation by appropriate keys
    # Saving them into new variables
    x_validation = f['x_validation']  # HDF5 dataset
    y_validation = f['y_validation']  # HDF5 dataset
    # Converting them into Numpy arrays
    x_validation = np.array(x_validation)  # Numpy arrays
    y_validation = np.array(y_validation)  # Numpy arrays
    
    
    # Extracting saved arrays for testing by appropriate keys
    # Saving them into new variables
    x_test = f['x_test']  # HDF5 dataset
    y_test = f['y_test']  # HDF5 dataset
    # Converting them into Numpy arrays
    x_test = np.array(x_test)  # Numpy arrays
    y_test = np.array(y_test)  # Numpy arrays
# Out:
# ['x_test', 'x_train', 'x_validation', 'y_test', 'y_train', 'y_validation']

# %%
# Showing types of loaded arrays
print(type(x_train))
print(type(y_train))
print(type(x_validation))
print(type(y_validation))
print(type(x_test))
print(type(y_test))
print()


# Showing shapes of loaded arrays
print(x_train.shape)
print(y_train.shape)
print(x_validation.shape)
print(y_validation.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
#
# (3240, 64, 64, 3)
# (3240,)
# (1110, 64, 64, 3)
# (1110,)
# (278, 64, 64, 3)
# (278,)

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Converting classes vectors to classes matrices

# %%
# Showing class index from the vector
print('Class index from vector:', y_train[3])
print()

# Preparing classes to be passed into the model
# Transforming them from vectors to binary matrices
# It is needed to set relationship between classes to be understood by the algorithm
# Such format is commonly used in training and predicting
y_train = to_categorical(y_train, num_classes = 5)
y_validation = to_categorical(y_validation, num_classes = 5)


# Showing shapes of converted vectors into matrices
print(y_train.shape)
print(y_validation.shape)
print()


# Showing class index from the matrix
print('Class index from matrix:', y_train[3])
# Out:
# Class index from vector: 4
#
# (3240, 5)
# (1110, 5)
#
# Class index from matrix: [0. 0. 0. 0. 1.]

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Choosing percentage of dropout

# %%
# Building 5 models
# RGB --> {64C5-P2} --> {128C5-P2} --> {256C5-P2} --> {512C5-P2} --> 2048 --> 5
# RGB --> {64C5-P2-D10} --> {128C5-P2-D10} --> {256C5-P2-D10} --> {512C5-P2-D10} --> 2048-D10 --> 5
# RGB --> {64C5-P2-D20} --> {128C5-P2-D20} --> {256C5-P2-D20} --> {512C5-P2-D20} --> 2048-D20 --> 5
# RGB --> {64C5-P2-D30} --> {128C5-P2-D30} --> {256C5-P2-D30} --> {512C5-P2-D30} --> 2048-D30 --> 5
# RGB --> {64C5-P2-D40} --> {128C5-P2-D40} --> {256C5-P2-D40} --> {512C5-P2-D40} --> 2048-D40 --> 5


# Defining list to collect models in
model = []


# Building models in a loop
for i in range(5):
    # Initializing model to be as linear stack of layers
    temp = Sequential()

    # Adding first convolutional-pooling pair
    temp.add(Conv2D(64, kernel_size=5, padding='same', activation='relu', input_shape=(64, 64, 3)))
    temp.add(MaxPool2D())
    temp.add(Dropout(0.1 * i))

    # Adding second convolutional-pooling pair
    temp.add(Conv2D(128, kernel_size=5, padding='same', activation='relu'))
    temp.add(MaxPool2D())
    temp.add(Dropout(0.1 * i))

    # Adding third convolutional-pooling pair
    temp.add(Conv2D(256, kernel_size=5, padding='same', activation='relu'))
    temp.add(MaxPool2D())
    temp.add(Dropout(0.1 * i))

    # Adding fourth convolutional-pooling pair
    temp.add(Conv2D(512, kernel_size=5, padding='same', activation='relu'))
    temp.add(MaxPool2D())
    temp.add(Dropout(0.1 * i))

    # Adding fully connected layers
    temp.add(Flatten())
    temp.add(Dense(2048, activation='relu'))
    temp.add(Dropout(0.1 * i))
    temp.add(Dense(5, activation='softmax'))

    # Compiling created model
    temp.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Adding current model in the list
    model.append(temp)


# Check point
print('5 models are compiled successfully')
# Out:
# 5 models are compiled successfully

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Visualizing built CNN models

# %%
# Plotting model's layers in form of flowchart
plot_model(model[4],
           to_file='model.png',
           show_shapes=True,
           show_layer_names=False,
           rankdir='TB',
           dpi=500)

# %%
# Showing model's summary in form of table
model[4].summary()

# %%
# Showing dropout rate
model[4].layers[2].rate

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Setting up learning rate & epochs

# %%
# Defining number of epochs
epochs = 20

# Defining schedule to update learning rate
learning_rate = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** (x + epochs), verbose=1)

# Check point
print('Number of epochs and schedule for learning rate are set successfully')
# Out:
# Number of epochs and schedule for learning rate are set successfully

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Training built CNN models

# %%
# Defining list to collect results in
h = []


# Training models in a loop
for i in range(5):
    # Current model
    temp = model[i].fit(x_train, y_train,
                        batch_size=50,
                        epochs=epochs,
                        validation_data=(x_validation, y_validation),
                        callbacks=[learning_rate],
                        verbose=1)
    
    # Adding results of current model in the list
    h.append(temp)
# Out:
# Train on 3240 samples, validate on 1110 samples
# Epoch 1/20
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0003584859224085419.
# 3240/3240 [==============================] - 71s 22ms/step - loss: 1.3328 - accuracy: 0.4213 - val_loss: 1.1618 - val_accuracy: 0.4910
# Epoch 2/20
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# 3240/3240 [==============================] - 70s 22ms/step - loss: 1.0609 - accuracy: 0.5454 - val_loss: 1.0190 - val_accuracy: 0.5703
# Epoch 3/20
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000323533544973709.
# 3240/3240 [==============================] - 67s 21ms/step - loss: 0.9477 - accuracy: 0.6037 - val_loss: 0.9207 - val_accuracy: 0.6135
# Epoch 4/20
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# 3240/3240 [==============================] - 62s 19ms/step - loss: 0.8264 - accuracy: 0.6488 - val_loss: 0.8911 - val_accuracy: 0.6054
# Epoch 5/20
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# 3240/3240 [==============================] - 63s 19ms/step - loss: 0.7341 - accuracy: 0.7043 - val_loss: 1.0131 - val_accuracy: 0.6279
# Epoch 6/20
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# 3240/3240 [==============================] - 63s 19ms/step - loss: 0.6323 - accuracy: 0.7441 - val_loss: 0.8503 - val_accuracy: 0.6477
# Epoch 7/20
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# 3240/3240 [==============================] - 63s 19ms/step - loss: 0.4984 - accuracy: 0.8000 - val_loss: 0.9030 - val_accuracy: 0.6495
# Epoch 8/20
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# 3240/3240 [==============================] - 62s 19ms/step - loss: 0.3497 - accuracy: 0.8688 - val_loss: 1.0683 - val_accuracy: 0.6477
# Epoch 9/20
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# 3240/3240 [==============================] - 69s 21ms/step - loss: 0.2290 - accuracy: 0.9201 - val_loss: 1.0172 - val_accuracy: 0.6820
# Epoch 10/20
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# 3240/3240 [==============================] - 71s 22ms/step - loss: 0.1029 - accuracy: 0.9676 - val_loss: 1.2806 - val_accuracy: 0.6640
# Epoch 11/20
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.0437 - accuracy: 0.9910 - val_loss: 1.5689 - val_accuracy: 0.6613
# Epoch 12/20
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.0126 - accuracy: 0.9985 - val_loss: 1.6965 - val_accuracy: 0.6739
# Epoch 13/20
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# 3240/3240 [==============================] - 67s 21ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 1.8507 - val_accuracy: 0.6847
# Epoch 14/20
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.9261 - val_accuracy: 0.6838
# Epoch 15/20
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000174824614723797.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 8.9594e-04 - accuracy: 1.0000 - val_loss: 2.0057 - val_accuracy: 0.6847
# Epoch 16/20
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 6.6748e-04 - accuracy: 1.0000 - val_loss: 2.0480 - val_accuracy: 0.6856
# Epoch 17/20
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 5.3808e-04 - accuracy: 1.0000 - val_loss: 2.0946 - val_accuracy: 0.6856
# Epoch 18/20
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# 3240/3240 [==============================] - 63s 20ms/step - loss: 4.5157e-04 - accuracy: 1.0000 - val_loss: 2.1359 - val_accuracy: 0.6838
# Epoch 19/20
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 3.9125e-04 - accuracy: 1.0000 - val_loss: 2.1599 - val_accuracy: 0.6820
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 3.4295e-04 - accuracy: 1.0000 - val_loss: 2.1885 - val_accuracy: 0.6820
# Train on 3240 samples, validate on 1110 samples
# Epoch 1/20
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0003584859224085419.
# 3240/3240 [==============================] - 77s 24ms/step - loss: 1.3778 - accuracy: 0.3688 - val_loss: 1.2062 - val_accuracy: 0.4622
# Epoch 2/20
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# 3240/3240 [==============================] - 68s 21ms/step - loss: 1.1347 - accuracy: 0.5003 - val_loss: 1.1020 - val_accuracy: 0.5099
# Epoch 3/20
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000323533544973709.
# 3240/3240 [==============================] - 70s 22ms/step - loss: 1.0244 - accuracy: 0.5525 - val_loss: 0.9747 - val_accuracy: 0.5919
# Epoch 4/20
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# 3240/3240 [==============================] - 71s 22ms/step - loss: 0.9277 - accuracy: 0.6086 - val_loss: 0.9412 - val_accuracy: 0.6153
# Epoch 5/20
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# 3240/3240 [==============================] - 68s 21ms/step - loss: 0.8304 - accuracy: 0.6571 - val_loss: 0.9038 - val_accuracy: 0.6414
# Epoch 6/20
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.7521 - accuracy: 0.6812 - val_loss: 0.8953 - val_accuracy: 0.6378
# Epoch 7/20
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# 3240/3240 [==============================] - 77s 24ms/step - loss: 0.6549 - accuracy: 0.7352 - val_loss: 0.8415 - val_accuracy: 0.6703
# Epoch 8/20
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# 3240/3240 [==============================] - 70s 22ms/step - loss: 0.5705 - accuracy: 0.7685 - val_loss: 0.9044 - val_accuracy: 0.6523
# Epoch 9/20
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# 3240/3240 [==============================] - 67s 21ms/step - loss: 0.4499 - accuracy: 0.8309 - val_loss: 0.9208 - val_accuracy: 0.6505
# Epoch 10/20
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.3258 - accuracy: 0.8707 - val_loss: 1.0721 - val_accuracy: 0.6532
# Epoch 11/20
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.2129 - accuracy: 0.9238 - val_loss: 1.0964 - val_accuracy: 0.6622
# Epoch 12/20
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.1482 - accuracy: 0.9494 - val_loss: 1.3015 - val_accuracy: 0.6586
# Epoch 13/20
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.0865 - accuracy: 0.9762 - val_loss: 1.4049 - val_accuracy: 0.6667
# Epoch 14/20
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.0479 - accuracy: 0.9861 - val_loss: 1.6686 - val_accuracy: 0.6586
# Epoch 15/20
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000174824614723797.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.0331 - accuracy: 0.9917 - val_loss: 1.7049 - val_accuracy: 0.6595
# Epoch 16/20
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.0279 - accuracy: 0.9938 - val_loss: 1.5937 - val_accuracy: 0.6622
# Epoch 17/20
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# 3240/3240 [==============================] - 63s 20ms/step - loss: 0.0187 - accuracy: 0.9960 - val_loss: 1.8205 - val_accuracy: 0.6595
# Epoch 18/20
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# 3240/3240 [==============================] - 63s 20ms/step - loss: 0.0098 - accuracy: 0.9991 - val_loss: 1.8773 - val_accuracy: 0.6613
# Epoch 19/20
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.0053 - accuracy: 0.9991 - val_loss: 1.9983 - val_accuracy: 0.6658
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# 3240/3240 [==============================] - 63s 20ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 2.1456 - val_accuracy: 0.6640
# Train on 3240 samples, validate on 1110 samples
# Epoch 1/20
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0003584859224085419.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 1.3970 - accuracy: 0.3873 - val_loss: 1.2736 - val_accuracy: 0.4514
# Epoch 2/20
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 1.1099 - accuracy: 0.5247 - val_loss: 1.0574 - val_accuracy: 0.5694
# Epoch 3/20
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000323533544973709.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.9754 - accuracy: 0.5836 - val_loss: 0.9584 - val_accuracy: 0.6126
# Epoch 4/20
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.9113 - accuracy: 0.6176 - val_loss: 0.9242 - val_accuracy: 0.6153
# Epoch 5/20
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.8388 - accuracy: 0.6448 - val_loss: 0.8915 - val_accuracy: 0.6351
# Epoch 6/20
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.7898 - accuracy: 0.6688 - val_loss: 0.8421 - val_accuracy: 0.6378
# Epoch 7/20
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.7140 - accuracy: 0.7062 - val_loss: 0.8086 - val_accuracy: 0.6631
# Epoch 8/20
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.6394 - accuracy: 0.7429 - val_loss: 0.8589 - val_accuracy: 0.6441
# Epoch 9/20
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.5598 - accuracy: 0.7769 - val_loss: 0.8618 - val_accuracy: 0.6550
# Epoch 10/20
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.4686 - accuracy: 0.8194 - val_loss: 0.9961 - val_accuracy: 0.6441
# Epoch 11/20
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.3751 - accuracy: 0.8583 - val_loss: 0.8787 - val_accuracy: 0.6784
# Epoch 12/20
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.2918 - accuracy: 0.8864 - val_loss: 0.9820 - val_accuracy: 0.6595
# Epoch 13/20
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.2241 - accuracy: 0.9179 - val_loss: 1.0530 - val_accuracy: 0.6613
# Epoch 14/20
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.1712 - accuracy: 0.9392 - val_loss: 1.1996 - val_accuracy: 0.6486
# Epoch 15/20
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000174824614723797.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.1140 - accuracy: 0.9648 - val_loss: 1.2673 - val_accuracy: 0.6676
# Epoch 16/20
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.0839 - accuracy: 0.9772 - val_loss: 1.3269 - val_accuracy: 0.6730
# Epoch 17/20
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.0629 - accuracy: 0.9796 - val_loss: 1.4166 - val_accuracy: 0.6820
# Epoch 18/20
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.0631 - accuracy: 0.9799 - val_loss: 1.3811 - val_accuracy: 0.6793
# Epoch 19/20
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.0312 - accuracy: 0.9920 - val_loss: 1.5344 - val_accuracy: 0.6838
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.0271 - accuracy: 0.9932 - val_loss: 1.5105 - val_accuracy: 0.6811
# Train on 3240 samples, validate on 1110 samples
# Epoch 1/20
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0003584859224085419.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 1.4976 - accuracy: 0.3469 - val_loss: 1.2855 - val_accuracy: 0.4550
# Epoch 2/20
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 1.1694 - accuracy: 0.4938 - val_loss: 1.1639 - val_accuracy: 0.5261
# Epoch 3/20
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000323533544973709.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 1.0461 - accuracy: 0.5586 - val_loss: 1.0940 - val_accuracy: 0.5505
# Epoch 4/20
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# 3240/3240 [==============================] - 67s 21ms/step - loss: 0.9848 - accuracy: 0.5790 - val_loss: 0.9897 - val_accuracy: 0.6144
# Epoch 5/20
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.9093 - accuracy: 0.6120 - val_loss: 0.9283 - val_accuracy: 0.6360
# Epoch 6/20
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.8384 - accuracy: 0.6438 - val_loss: 0.8569 - val_accuracy: 0.6396
# Epoch 7/20
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.7805 - accuracy: 0.6769 - val_loss: 0.8529 - val_accuracy: 0.6586
# Epoch 8/20
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.7397 - accuracy: 0.6929 - val_loss: 0.8362 - val_accuracy: 0.6595
# Epoch 9/20
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.6927 - accuracy: 0.7179 - val_loss: 0.8475 - val_accuracy: 0.6586
# Epoch 10/20
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.6254 - accuracy: 0.7426 - val_loss: 0.8196 - val_accuracy: 0.6604
# Epoch 11/20
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.5638 - accuracy: 0.7642 - val_loss: 0.8515 - val_accuracy: 0.6793
# Epoch 12/20
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# 3240/3240 [==============================] - 67s 21ms/step - loss: 0.5035 - accuracy: 0.8015 - val_loss: 0.7877 - val_accuracy: 0.6946
# Epoch 13/20
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.4381 - accuracy: 0.8290 - val_loss: 0.8612 - val_accuracy: 0.6712
# Epoch 14/20
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.3618 - accuracy: 0.8596 - val_loss: 0.8898 - val_accuracy: 0.6838
# Epoch 15/20
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000174824614723797.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.3090 - accuracy: 0.8833 - val_loss: 0.9577 - val_accuracy: 0.6748
# Epoch 16/20
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.2488 - accuracy: 0.9090 - val_loss: 0.9767 - val_accuracy: 0.6757
# Epoch 17/20
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.1947 - accuracy: 0.9343 - val_loss: 1.0354 - val_accuracy: 0.6919
# Epoch 18/20
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.1775 - accuracy: 0.9352 - val_loss: 1.0715 - val_accuracy: 0.6730
# Epoch 19/20
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.1491 - accuracy: 0.9457 - val_loss: 1.1365 - val_accuracy: 0.6838
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.1062 - accuracy: 0.9642 - val_loss: 1.2108 - val_accuracy: 0.6883
# Train on 3240 samples, validate on 1110 samples
# Epoch 1/20
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0003584859224085419.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 1.4858 - accuracy: 0.3404 - val_loss: 1.3311 - val_accuracy: 0.3982
# Epoch 2/20
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 1.2090 - accuracy: 0.4698 - val_loss: 1.2270 - val_accuracy: 0.5018
# Epoch 3/20
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000323533544973709.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 1.1001 - accuracy: 0.5160 - val_loss: 1.0718 - val_accuracy: 0.5622
# Epoch 4/20
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.9985 - accuracy: 0.5728 - val_loss: 1.0438 - val_accuracy: 0.5748
# Epoch 5/20
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.9469 - accuracy: 0.5972 - val_loss: 1.0203 - val_accuracy: 0.5955
# Epoch 6/20
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.9248 - accuracy: 0.6117 - val_loss: 0.9411 - val_accuracy: 0.6324
# Epoch 7/20
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.8633 - accuracy: 0.6333 - val_loss: 0.8978 - val_accuracy: 0.6396
# Epoch 8/20
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.8172 - accuracy: 0.6605 - val_loss: 0.8437 - val_accuracy: 0.6577
# Epoch 9/20
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.7761 - accuracy: 0.6731 - val_loss: 0.8994 - val_accuracy: 0.6324
# Epoch 10/20
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.7451 - accuracy: 0.6941 - val_loss: 0.8288 - val_accuracy: 0.6649
# Epoch 11/20
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.7060 - accuracy: 0.7037 - val_loss: 0.8338 - val_accuracy: 0.6622
# Epoch 12/20
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.6644 - accuracy: 0.7228 - val_loss: 0.7878 - val_accuracy: 0.6730
# Epoch 13/20
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# 3240/3240 [==============================] - 65s 20ms/step - loss: 0.6225 - accuracy: 0.7488 - val_loss: 0.7927 - val_accuracy: 0.6820
# Epoch 14/20
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.5856 - accuracy: 0.7673 - val_loss: 0.7637 - val_accuracy: 0.6775
# Epoch 15/20
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000174824614723797.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.5425 - accuracy: 0.7830 - val_loss: 0.8150 - val_accuracy: 0.6820
# Epoch 16/20
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.4991 - accuracy: 0.7981 - val_loss: 0.7665 - val_accuracy: 0.6928
# Epoch 17/20
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.4407 - accuracy: 0.8244 - val_loss: 0.7860 - val_accuracy: 0.6730
# Epoch 18/20
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.4093 - accuracy: 0.8426 - val_loss: 0.8065 - val_accuracy: 0.6775
# Epoch 19/20
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.3635 - accuracy: 0.8590 - val_loss: 0.8238 - val_accuracy: 0.6865
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 0.3094 - accuracy: 0.8735 - val_loss: 0.8339 - val_accuracy: 0.6928

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Showing and plotting accuracies

# %%
# Accuracies of the models
for i in range(5):
    print('Model {0}: Training accuracy={1:.5f}, Validation accuracy={2:.5f}'.
                                                         format(i + 1,
                                                                max(h[i].history['accuracy']),
                                                                max(h[i].history['val_accuracy'])))
# Out:
# Model 1: Training accuracy=1.00000, Validation accuracy=0.68559
# Model 2: Training accuracy=0.99907, Validation accuracy=0.67027
# Model 3: Training accuracy=0.99321, Validation accuracy=0.68378
# Model 4: Training accuracy=0.96420, Validation accuracy=0.69459
# Model 5: Training accuracy=0.87346, Validation accuracy=0.69279

# %%
# Magic function that renders the figure in a jupyter notebook
# instead of displaying a figure object
# %matplotlib inline


# Setting default size of the plot
plt.rcParams['figure.figsize'] = (12.0, 6.0)


# Plotting accuracies for every model
plt.plot(h[0].history['val_accuracy'], '-o')
plt.plot(h[1].history['val_accuracy'], '-o')
plt.plot(h[2].history['val_accuracy'], '-o')
plt.plot(h[3].history['val_accuracy'], '-o')
plt.plot(h[4].history['val_accuracy'], '-o')


# Setting limit along Y axis
plt.ylim(0.62, 0.72)


# Showing legend
plt.legend(['model_1', 'model_2', 'model_3', 'model_4', 'model_5'],
           loc='lower right',
           fontsize='xx-large')


# Giving name to axes
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)


# Giving name to the plot
plt.title('Models accuracies: Custom Dataset', fontsize=16)


# Showing the plot
plt.show()

# %%
# Showing list of scheduled learning rate for every epoch
print(h[0].history['lr'])
# Out:
# [0.00035848594, 0.00034056162, 0.00032353355, 0.00030735688, 0.000291989, 0.00027738957, 0.0002635201, 0.00025034408, 0.00023782688, 0.00022593554, 0.00021463877, 0.00020390682, 0.00019371149, 0.0001840259, 0.00017482461, 0.00016608338, 0.00015777921, 0.00014989026, 0.00014239574, 0.00013527596]

# %%
# Magic function that renders the figure in a jupyter notebook
# instead of displaying a figure object
# %matplotlib inline


# Plotting scheduled learning rate
plt.plot(h[0].history['lr'], '-mo')


# Showing the plot
plt.show()

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Step 8: Making a conclusion

# %%
# According to validation accuracy, the 3rd model has the highest value

# The choice for custom dataset is 3rd model
# RGB input --> {64C5-P2-D20} --> {128C5-P2-D20} --> {256C5-P2-D20} --> {512C5-P2-D20} --> 2048-D20 --> 5
# GRAY input --> {64C5-P2-D20} --> {128C5-P2-D20} --> {256C5-P2-D20} --> {512C5-P2-D20} --> 2048-D20 --> 5

# RGB input: (64, 64, 3)
# GRAY input: (64, 64, 1)
