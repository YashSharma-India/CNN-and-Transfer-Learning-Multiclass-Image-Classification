# %% [markdown]
# # Construct deep architectures for CNN models
#
#
# ### **Description: Needed amount of neurons for output layer Interpret notation**

# %% [markdown]
# ### Algorithm:
#
# **--> Step 1:** Open preprocessed dataset
# **--> Step 2:** Convert classes vectors to binary matrices
# **--> Step 3:** Choose **number of neurons in output layer**
# **--> Step 4:** Visualize built CNN models
# **--> Step 5:** Set up learning rate & epochs
# **--> Step 6:** Train built CNN models
# **--> Step 7:** Show and plot accuracies
# **--> Step 8:** Make a conclusion
#
#
# **Result:**
# - Chosen architecture for every preprocessed dataset

# %% [markdown]
# ## Importing libraries

# %%
# Importing needed libraries
import matplotlib.pyplot as plt
import numpy as np
import h5py


from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense
from tensorflow.keras.callbacks import LearningRateScheduler
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Setting up full path to preprocessed datasets

# %%
# Full or absolute path to preprocessed datasets
full_path_to_code = \
    'C:/Users/yashs/PycharmProjects/InternshipCNN/TCS'

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Step 1: Opening preprocessed dataset

# %%
# Opening saved custom dataset from HDF5 binary file
# Initiating File object
# Opening file in reading mode by 'r'
with h5py.File(full_path_to_code + '/' + 'custom' + '/' + 
               'dataset_custom_rgb_255_mean_std.hdf5', 'r') as f:
    
    # Showing all keys in the HDF5 binary file
    print(list(f.keys()))
    
    # Extracting saved arrays for training by appropriate keys
    # Saving them into new variables
    x_train = f['x_train']  # HDF5 dataset
    y_train = f['y_train']  # HDF5 dataset
    # Converting them into Numpy arrays
    x_train = np.array(x_train)  # Numpy arrays
    y_train = np.array(y_train)  # Numpy arrays
    
    
    # Extracting saved arrays for validation by appropriate keys
    # Saving them into new variables
    x_validation = f['x_validation']  # HDF5 dataset
    y_validation = f['y_validation']  # HDF5 dataset
    # Converting them into Numpy arrays
    x_validation = np.array(x_validation)  # Numpy arrays
    y_validation = np.array(y_validation)  # Numpy arrays
    
    
    # Extracting saved arrays for testing by appropriate keys
    # Saving them into new variables
    x_test = f['x_test']  # HDF5 dataset
    y_test = f['y_test']  # HDF5 dataset
    # Converting them into Numpy arrays
    x_test = np.array(x_test)  # Numpy arrays
    y_test = np.array(y_test)  # Numpy arrays
# Out:
# ['x_test', 'x_train', 'x_validation', 'y_test', 'y_train', 'y_validation']

# %%
# Showing types of loaded arrays
print(type(x_train))
print(type(y_train))
print(type(x_validation))
print(type(y_validation))
print(type(x_test))
print(type(y_test))
print()


# Showing shapes of loaded arrays
print(x_train.shape)
print(y_train.shape)
print(x_validation.shape)
print(y_validation.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
#
# (3240, 64, 64, 3)
# (3240,)
# (1110, 64, 64, 3)
# (1110,)
# (278, 64, 64, 3)
# (278,)

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Step 2: Converting classes vectors to classes matrices

# %%
# Showing class index from the vector
print('Class index from vector:', y_train[2])
print()

# Preparing classes to be passed into the model
# Transforming them from vectors to binary matrices
# It is needed to set relationship between classes to be understood by the algorithm
# Such format is commonly used in training and predicting
y_train = to_categorical(y_train, num_classes = 5)
y_validation = to_categorical(y_validation, num_classes = 5)


# Showing shapes of converted vectors into matrices
print(y_train.shape)
print(y_validation.shape)
print()


# Showing class index from the matrix
print('Class index from matrix:', y_train[2])
# Out:
# Class index from vector: 0
#
# (3240, 5)
# (1110, 5)
#
# Class index from matrix: [1. 0. 0. 0. 0.]

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Step 3: Choosing number of neurons in output layer

# %%
# Building 5 models
# RGB --> {64C5-P2} --> {128C5-P2} --> {256C5-P2} --> {512C5-P2} --> 128 --> 5
# RGB --> {64C5-P2} --> {128C5-P2} --> {256C5-P2} --> {512C5-P2} --> 256 --> 5
# RGB --> {64C5-P2} --> {128C5-P2} --> {256C5-P2} --> {512C5-P2} --> 512 --> 5
# RGB --> {64C5-P2} --> {128C5-P2} --> {256C5-P2} --> {512C5-P2} --> 1024 --> 5
# RGB --> {64C5-P2} --> {128C5-P2} --> {256C5-P2} --> {512C5-P2} --> 2048 --> 5


# Defining list to collect models in
model = []


# Building models in a loop
for i in range(5):
    # Initializing model to be as linear stack of layers
    temp = Sequential()

    # Adding first convolutional-pooling pair
    temp.add(Conv2D(64, kernel_size=5, padding='same', activation='relu', input_shape=(64, 64, 3)))
    temp.add(MaxPool2D())

    # Adding second convolutional-pooling pair
    temp.add(Conv2D(128, kernel_size=5, padding='same', activation='relu'))
    temp.add(MaxPool2D())

    # Adding third convolutional-pooling pair
    temp.add(Conv2D(256, kernel_size=5, padding='same', activation='relu'))
    temp.add(MaxPool2D())

    # Adding fourth convolutional-pooling pair
    temp.add(Conv2D(512, kernel_size=5, padding='same', activation='relu'))
    temp.add(MaxPool2D())

    # Adding fully connected layers
    temp.add(Flatten())
    temp.add(Dense(128 * (2 ** i), activation='relu'))
    temp.add(Dense(5, activation='softmax'))

    # Compiling created model
    temp.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Adding current model in the list
    model.append(temp)


# Check point
print('5 models are compiled successfully')
# Out:
# 5 models are compiled successfully

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Step 4: Visualizing built CNN models

# %%
# Plotting model's layers in form of flowchart
plot_model(model[4],
           to_file='model.png',
           show_shapes=True,
           show_layer_names=False,
           rankdir='TB',
           dpi=500)

# %%
# Showing model's summary in form of table
model[4].summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 64, 64, 64)        4864
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 32, 32, 128)       204928
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 16, 16, 256)       819456
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 8, 8, 512)         3277312
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2048)              16779264
# _________________________________________________________________
# dense_10 (Dense)             (None, 5)                 10245
# =================================================================
# Total params: 21,096,069
# Trainable params: 21,096,069
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Step 5: Setting up learning rate & epochs

# %%
# Defining number of epochs
epochs = 20

# Defining schedule to update learning rate
learning_rate = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** (x + epochs), verbose=1)

# Check point
print('Number of epochs and schedule for learning rate are set successfully')
# Out:
# Number of epochs and schedule for learning rate are set successfully

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Step 6: Training built CNN models

# %%
# Defining list to collect results in
h = []


# Training models in a loop
for i in range(5):
    # Current model
    temp = model[i].fit(x_train, y_train,
                        batch_size=50,
                        epochs=epochs,
                        validation_data=(x_validation, y_validation),
                        callbacks=[learning_rate],
                        verbose=1)
    
    # Adding results of current model in the list
    h.append(temp)
# Out:
# Train on 3240 samples, validate on 1110 samples
# Epoch 1/20
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0003584859224085419.
# 3240/3240 [==============================] - 48s 15ms/step - loss: 1.3015 - accuracy: 0.4145 - val_loss: 1.1661 - val_accuracy: 0.5108
# Epoch 2/20
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# 3240/3240 [==============================] - 49s 15ms/step - loss: 1.0418 - accuracy: 0.5590 - val_loss: 1.0570 - val_accuracy: 0.5730
# Epoch 3/20
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000323533544973709.
# 3240/3240 [==============================] - 52s 16ms/step - loss: 0.9228 - accuracy: 0.6120 - val_loss: 0.9320 - val_accuracy: 0.6108
# Epoch 4/20
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# 3240/3240 [==============================] - 50s 16ms/step - loss: 0.8357 - accuracy: 0.6488 - val_loss: 0.8827 - val_accuracy: 0.6477
# Epoch 5/20
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# 3240/3240 [==============================] - 49s 15ms/step - loss: 0.7340 - accuracy: 0.6994 - val_loss: 0.8247 - val_accuracy: 0.6667
# Epoch 6/20
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# 3240/3240 [==============================] - 49s 15ms/step - loss: 0.6380 - accuracy: 0.7469 - val_loss: 0.8935 - val_accuracy: 0.6432
# Epoch 7/20
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.5306 - accuracy: 0.7981 - val_loss: 0.8879 - val_accuracy: 0.6730
# Epoch 8/20
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# 3240/3240 [==============================] - 50s 15ms/step - loss: 0.4009 - accuracy: 0.8528 - val_loss: 0.8702 - val_accuracy: 0.6739
# Epoch 9/20
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.2591 - accuracy: 0.9102 - val_loss: 1.0049 - val_accuracy: 0.6775
# Epoch 10/20
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# 3240/3240 [==============================] - 52s 16ms/step - loss: 0.1346 - accuracy: 0.9593 - val_loss: 1.2631 - val_accuracy: 0.6640
# Epoch 11/20
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# 3240/3240 [==============================] - 50s 15ms/step - loss: 0.0704 - accuracy: 0.9824 - val_loss: 1.2672 - val_accuracy: 0.6730
# Epoch 12/20
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.0257 - accuracy: 0.9966 - val_loss: 1.4975 - val_accuracy: 0.6730
# Epoch 13/20
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.6401 - val_accuracy: 0.6847
# Epoch 14/20
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# 3240/3240 [==============================] - 49s 15ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.6837 - val_accuracy: 0.6937
# Epoch 15/20
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000174824614723797.
# 3240/3240 [==============================] - 50s 15ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.7601 - val_accuracy: 0.6937
# Epoch 16/20
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# 3240/3240 [==============================] - 50s 15ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.8200 - val_accuracy: 0.6946
# Epoch 17/20
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# 3240/3240 [==============================] - 52s 16ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.8653 - val_accuracy: 0.6982
# Epoch 18/20
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 9.6757e-04 - accuracy: 1.0000 - val_loss: 1.9111 - val_accuracy: 0.6919
# Epoch 19/20
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# 3240/3240 [==============================] - 52s 16ms/step - loss: 8.1965e-04 - accuracy: 1.0000 - val_loss: 1.9308 - val_accuracy: 0.6937
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# 3240/3240 [==============================] - 52s 16ms/step - loss: 7.1969e-04 - accuracy: 1.0000 - val_loss: 1.9589 - val_accuracy: 0.6955
# Train on 3240 samples, validate on 1110 samples
# Epoch 1/20
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0003584859224085419.
# 3240/3240 [==============================] - 53s 16ms/step - loss: 1.3221 - accuracy: 0.3948 - val_loss: 1.1378 - val_accuracy: 0.5153
# Epoch 2/20
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# 3240/3240 [==============================] - 53s 16ms/step - loss: 1.0753 - accuracy: 0.5306 - val_loss: 1.0495 - val_accuracy: 0.5649
# Epoch 3/20
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000323533544973709.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.9386 - accuracy: 0.6049 - val_loss: 0.9746 - val_accuracy: 0.6000
# Epoch 4/20
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# 3240/3240 [==============================] - 55s 17ms/step - loss: 0.8660 - accuracy: 0.6435 - val_loss: 0.9326 - val_accuracy: 0.6000
# Epoch 5/20
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.7605 - accuracy: 0.6849 - val_loss: 0.8422 - val_accuracy: 0.6468
# Epoch 6/20
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# 3240/3240 [==============================] - 53s 16ms/step - loss: 0.6538 - accuracy: 0.7346 - val_loss: 0.8216 - val_accuracy: 0.6658
# Epoch 7/20
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# 3240/3240 [==============================] - 53s 16ms/step - loss: 0.5458 - accuracy: 0.7821 - val_loss: 0.9031 - val_accuracy: 0.6505
# Epoch 8/20
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# 3240/3240 [==============================] - 55s 17ms/step - loss: 0.4225 - accuracy: 0.8444 - val_loss: 0.8945 - val_accuracy: 0.6793
# Epoch 9/20
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.2535 - accuracy: 0.9136 - val_loss: 0.9205 - val_accuracy: 0.6703
# Epoch 10/20
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# 3240/3240 [==============================] - 56s 17ms/step - loss: 0.1290 - accuracy: 0.9627 - val_loss: 1.1698 - val_accuracy: 0.6604
# Epoch 11/20
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# 3240/3240 [==============================] - 59s 18ms/step - loss: 0.0551 - accuracy: 0.9883 - val_loss: 1.3080 - val_accuracy: 0.6838
# Epoch 12/20
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# 3240/3240 [==============================] - 57s 17ms/step - loss: 0.0293 - accuracy: 0.9941 - val_loss: 1.6756 - val_accuracy: 0.6613
# Epoch 13/20
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# 3240/3240 [==============================] - 52s 16ms/step - loss: 0.0264 - accuracy: 0.9951 - val_loss: 1.6058 - val_accuracy: 0.6748
# Epoch 14/20
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.0086 - accuracy: 0.9997 - val_loss: 1.6988 - val_accuracy: 0.6820
# Epoch 15/20
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000174824614723797.
# 3240/3240 [==============================] - 52s 16ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.7725 - val_accuracy: 0.6793
# Epoch 16/20
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# 3240/3240 [==============================] - 53s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.8547 - val_accuracy: 0.6793
# Epoch 17/20
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# 3240/3240 [==============================] - 50s 15ms/step - loss: 9.5145e-04 - accuracy: 1.0000 - val_loss: 1.9019 - val_accuracy: 0.6811
# Epoch 18/20
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# 3240/3240 [==============================] - 50s 15ms/step - loss: 7.6366e-04 - accuracy: 1.0000 - val_loss: 1.9441 - val_accuracy: 0.6811
# Epoch 19/20
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# 3240/3240 [==============================] - 50s 15ms/step - loss: 6.3558e-04 - accuracy: 1.0000 - val_loss: 1.9789 - val_accuracy: 0.6811
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# 3240/3240 [==============================] - 50s 15ms/step - loss: 5.5375e-04 - accuracy: 1.0000 - val_loss: 2.0047 - val_accuracy: 0.6811
# Train on 3240 samples, validate on 1110 samples
# Epoch 1/20
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0003584859224085419.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 1.3990 - accuracy: 0.3799 - val_loss: 1.2148 - val_accuracy: 0.4622
# Epoch 2/20
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 1.0959 - accuracy: 0.5383 - val_loss: 1.0056 - val_accuracy: 0.5802
# Epoch 3/20
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000323533544973709.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.9734 - accuracy: 0.5960 - val_loss: 0.9657 - val_accuracy: 0.6063
# Epoch 4/20
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.8642 - accuracy: 0.6367 - val_loss: 0.8655 - val_accuracy: 0.6468
# Epoch 5/20
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.7688 - accuracy: 0.6889 - val_loss: 0.8745 - val_accuracy: 0.6450
# Epoch 6/20
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.6576 - accuracy: 0.7367 - val_loss: 0.8369 - val_accuracy: 0.6604
# Epoch 7/20
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.5349 - accuracy: 0.7886 - val_loss: 0.8107 - val_accuracy: 0.6775
# Epoch 8/20
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# 3240/3240 [==============================] - 514s 159ms/step - loss: 0.4043 - accuracy: 0.8441 - val_loss: 0.9637 - val_accuracy: 0.6559
# Epoch 9/20
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# 3240/3240 [==============================] - 50s 15ms/step - loss: 0.2344 - accuracy: 0.9219 - val_loss: 1.0655 - val_accuracy: 0.6432
# Epoch 10/20
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# 3240/3240 [==============================] - 50s 16ms/step - loss: 0.1159 - accuracy: 0.9673 - val_loss: 1.2546 - val_accuracy: 0.6586
# Epoch 11/20
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.0545 - accuracy: 0.9861 - val_loss: 1.3669 - val_accuracy: 0.6721
# Epoch 12/20
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.0205 - accuracy: 0.9969 - val_loss: 1.5792 - val_accuracy: 0.6811
# Epoch 13/20
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.6867 - val_accuracy: 0.6829
# Epoch 14/20
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.7785 - val_accuracy: 0.6784
# Epoch 15/20
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000174824614723797.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.8408 - val_accuracy: 0.6829
# Epoch 16/20
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.9068 - val_accuracy: 0.6847
# Epoch 17/20
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 9.0056e-04 - accuracy: 1.0000 - val_loss: 1.9448 - val_accuracy: 0.6838
# Epoch 18/20
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 6.9567e-04 - accuracy: 1.0000 - val_loss: 1.9770 - val_accuracy: 0.6829
# Epoch 19/20
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# 3240/3240 [==============================] - 51s 16ms/step - loss: 5.9954e-04 - accuracy: 1.0000 - val_loss: 2.0198 - val_accuracy: 0.6811
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# 3240/3240 [==============================] - 52s 16ms/step - loss: 5.2427e-04 - accuracy: 1.0000 - val_loss: 2.0429 - val_accuracy: 0.6856
# Train on 3240 samples, validate on 1110 samples
# Epoch 1/20
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0003584859224085419.
# 3240/3240 [==============================] - 55s 17ms/step - loss: 1.3003 - accuracy: 0.4188 - val_loss: 1.1225 - val_accuracy: 0.5441
# Epoch 2/20
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 1.0328 - accuracy: 0.5679 - val_loss: 0.9445 - val_accuracy: 0.6099
# Epoch 3/20
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000323533544973709.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.9195 - accuracy: 0.6123 - val_loss: 0.9608 - val_accuracy: 0.6117
# Epoch 4/20
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.7930 - accuracy: 0.6762 - val_loss: 0.9031 - val_accuracy: 0.6387
# Epoch 5/20
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.6882 - accuracy: 0.7154 - val_loss: 0.8021 - val_accuracy: 0.6667
# Epoch 6/20
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.5234 - accuracy: 0.7920 - val_loss: 0.9020 - val_accuracy: 0.6459
# Epoch 7/20
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.3590 - accuracy: 0.8648 - val_loss: 1.0502 - val_accuracy: 0.6541
# Epoch 8/20
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.2167 - accuracy: 0.9235 - val_loss: 1.2527 - val_accuracy: 0.6514
# Epoch 9/20
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.0976 - accuracy: 0.9704 - val_loss: 1.3661 - val_accuracy: 0.6658
# Epoch 10/20
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.0359 - accuracy: 0.9917 - val_loss: 1.6433 - val_accuracy: 0.6739
# Epoch 11/20
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.0191 - accuracy: 0.9951 - val_loss: 1.7591 - val_accuracy: 0.6829
# Epoch 12/20
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.0121 - accuracy: 0.9972 - val_loss: 1.9226 - val_accuracy: 0.6631
# Epoch 13/20
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.0072 - accuracy: 0.9988 - val_loss: 1.9368 - val_accuracy: 0.6883
# Epoch 14/20
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.0413 - val_accuracy: 0.6937
# Epoch 15/20
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000174824614723797.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 6.0284e-04 - accuracy: 1.0000 - val_loss: 2.1151 - val_accuracy: 0.6964
# Epoch 16/20
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 4.5723e-04 - accuracy: 1.0000 - val_loss: 2.1677 - val_accuracy: 0.6964
# Epoch 17/20
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 3.7144e-04 - accuracy: 1.0000 - val_loss: 2.2091 - val_accuracy: 0.6946
# Epoch 18/20
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 3.1346e-04 - accuracy: 1.0000 - val_loss: 2.2417 - val_accuracy: 0.6946
# Epoch 19/20
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 2.7130e-04 - accuracy: 1.0000 - val_loss: 2.2731 - val_accuracy: 0.6964
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# 3240/3240 [==============================] - 54s 17ms/step - loss: 2.3739e-04 - accuracy: 1.0000 - val_loss: 2.2998 - val_accuracy: 0.6955
# Train on 3240 samples, validate on 1110 samples
# Epoch 1/20
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0003584859224085419.
# 3240/3240 [==============================] - 60s 18ms/step - loss: 1.3177 - accuracy: 0.4182 - val_loss: 1.1891 - val_accuracy: 0.4604
# Epoch 2/20
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# 3240/3240 [==============================] - 60s 18ms/step - loss: 1.0801 - accuracy: 0.5410 - val_loss: 1.0262 - val_accuracy: 0.5748
# Epoch 3/20
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000323533544973709.
# 3240/3240 [==============================] - 60s 18ms/step - loss: 0.9437 - accuracy: 0.6025 - val_loss: 0.9443 - val_accuracy: 0.6153
# Epoch 4/20
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# 3240/3240 [==============================] - 63s 20ms/step - loss: 0.8256 - accuracy: 0.6617 - val_loss: 0.8561 - val_accuracy: 0.6505
# Epoch 5/20
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# 3240/3240 [==============================] - 61s 19ms/step - loss: 0.7434 - accuracy: 0.6926 - val_loss: 0.8600 - val_accuracy: 0.6495
# Epoch 6/20
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# 3240/3240 [==============================] - 60s 18ms/step - loss: 0.6185 - accuracy: 0.7441 - val_loss: 0.8751 - val_accuracy: 0.6559
# Epoch 7/20
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# 3240/3240 [==============================] - 60s 18ms/step - loss: 0.4793 - accuracy: 0.8120 - val_loss: 0.9955 - val_accuracy: 0.6423
# Epoch 8/20
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# 3240/3240 [==============================] - 59s 18ms/step - loss: 0.3456 - accuracy: 0.8698 - val_loss: 1.1305 - val_accuracy: 0.6459
# Epoch 9/20
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# 3240/3240 [==============================] - 60s 18ms/step - loss: 0.1942 - accuracy: 0.9336 - val_loss: 1.1553 - val_accuracy: 0.6586
# Epoch 10/20
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# 3240/3240 [==============================] - 60s 18ms/step - loss: 0.0858 - accuracy: 0.9787 - val_loss: 1.3770 - val_accuracy: 0.6649
# Epoch 11/20
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# 3240/3240 [==============================] - 60s 18ms/step - loss: 0.0278 - accuracy: 0.9951 - val_loss: 1.5763 - val_accuracy: 0.6793
# Epoch 12/20
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# 3240/3240 [==============================] - 60s 18ms/step - loss: 0.0141 - accuracy: 0.9972 - val_loss: 1.8634 - val_accuracy: 0.6694
# Epoch 13/20
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.0129 - accuracy: 0.9972 - val_loss: 1.8793 - val_accuracy: 0.6748
# Epoch 14/20
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# 3240/3240 [==============================] - 63s 20ms/step - loss: 0.0286 - accuracy: 0.9926 - val_loss: 1.8258 - val_accuracy: 0.6676
# Epoch 15/20
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000174824614723797.
# 3240/3240 [==============================] - 69s 21ms/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 1.8615 - val_accuracy: 0.6703
# Epoch 16/20
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# 3240/3240 [==============================] - 64s 20ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.0003 - val_accuracy: 0.6685
# Epoch 17/20
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 8.0919e-04 - accuracy: 1.0000 - val_loss: 2.0547 - val_accuracy: 0.6685
# Epoch 18/20
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# 3240/3240 [==============================] - 66s 20ms/step - loss: 6.2608e-04 - accuracy: 1.0000 - val_loss: 2.1212 - val_accuracy: 0.6676
# Epoch 19/20
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# 3240/3240 [==============================] - 60s 19ms/step - loss: 4.9901e-04 - accuracy: 1.0000 - val_loss: 2.1599 - val_accuracy: 0.6676
# Epoch 20/20
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# 3240/3240 [==============================] - 67s 21ms/step - loss: 4.1960e-04 - accuracy: 1.0000 - val_loss: 2.2007 - val_accuracy: 0.6685

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Step 7: Showing and plotting accuracies

# %%
# Accuracies of the models
for i in range(5):
    print('Model {0}: Training accuracy={1:.5f}, Validation accuracy={2:.5f}'.
                                                          format(i + 1,
                                                                 max(h[i].history['accuracy']),
                                                                 max(h[i].history['val_accuracy'])))
# Out:
# Model 1: Training accuracy=1.00000, Validation accuracy=0.69820
# Model 2: Training accuracy=1.00000, Validation accuracy=0.68378
# Model 3: Training accuracy=1.00000, Validation accuracy=0.68559
# Model 4: Training accuracy=1.00000, Validation accuracy=0.69640
# Model 5: Training accuracy=1.00000, Validation accuracy=0.67928

# %%
# Magic function that renders the figure in a jupyter notebook
# instead of displaying a figure object
# %matplotlib inline


# Setting default size of the plot
plt.rcParams['figure.figsize'] = (12.0, 6.0)


# Plotting accuracies for every model
plt.plot(h[0].history['val_accuracy'], '-o')
plt.plot(h[1].history['val_accuracy'], '-o')
plt.plot(h[2].history['val_accuracy'], '-o')
plt.plot(h[3].history['val_accuracy'], '-o')
plt.plot(h[4].history['val_accuracy'], '-o')


# Setting limit along Y axis
plt.ylim(0.63, 0.715)


# Showing legend
plt.legend(['model_1', 'model_2', 'model_3', 'model_4', 'model_5'],
           loc='lower right',
           fontsize='xx-large')


# Giving name to axes
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)


# Giving name to the plot
plt.title('Models accuracies: Custom Dataset', fontsize=16)


# Showing the plot
plt.show()

# %%
# Showing list of scheduled learning rate for every epoch
print(h[0].history['lr'])
# Out:
# [0.00035848594, 0.00034056162, 0.00032353355, 0.00030735688, 0.000291989, 0.00027738957, 0.0002635201, 0.00025034408, 0.00023782688, 0.00022593554, 0.00021463877, 0.00020390682, 0.00019371149, 0.0001840259, 0.00017482461, 0.00016608338, 0.00015777921, 0.00014989026, 0.00014239574, 0.00013527596]

# %%
# Magic function that renders the figure in a jupyter notebook
# instead of displaying a figure object
# %matplotlib inline


# Plotting scheduled learning rate
plt.plot(h[0].history['lr'], '-mo')


# Showing the plot
plt.show()

# %% [markdown]
# ### RGB custom dataset (255.0 ==> mean ==> std)
#
# ## Step 8: Making a conclusion

# %%
# According to validation accuracy, the 2nd, 4th and 5th models have the highest values

# The choice for custom dataset is 5th model
# RGB input --> {64C5-P2} --> {128C5-P2} --> {256C5-P2} --> {512C5-P2} --> 2048 --> 5
# GRAY input --> {64C5-P2} --> {128C5-P2} --> {256C5-P2} --> {512C5-P2} --> 2048 --> 5

# RGB input: (64, 64, 3)
# GRAY input: (64, 64, 1)
